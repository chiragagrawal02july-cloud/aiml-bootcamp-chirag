# %%
Day1 Task

# %%
1. Types_practice.py

# %%
a = 1
b = 2
sum = a+b
print(sum)
print (type(a and b))
# Out:
# 3
# <class 'int'>

# %%
a = 3.14
print (type(a))
# Out:
# <class 'float'>

# %%
name = "chirag"
print(name)
print (type(name))
# Out:
# chirag
# <class 'str'>

# %%
chirag_is = True
chirag_are= False
print(chirag_are)
print(type(chirag_is))
# Out:
# False
# <class 'bool'>

# %%
fruits = ["banana", "orange", "kiwi"]
print(fruits)
print(type(fruits))
# Out:
# ['banana', 'orange', 'kiwi']
# <class 'list'>

# %%
student = {
    "name" : "chirag",
    "roll no" : 17,
    "marks" : 210,
}
print(student)
print(type(student))
# Out:
# {'name': 'chirag', 'roll no': 17, 'marks': 210}
# <class 'dict'>

# %%
name = ["chirag", 25]
print(name)
#syntax invailid we can not write the code in this way
# Out:
# ['chirag', 25]

# %%
2. Mutability.py

# %%
a = [1,2,3]
b = a
b.append(4)
print(a)
print(b)
#append add the number at the last so the value to a and b has been changed.
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
3. Collections_practice.py

# %%
name = {"asha", "ravi", "asha", "meera", "ravi"}
print(name)
print(type(name))
print(len(name))
# Out:
# {'ravi', 'meera', 'asha'}
# <class 'set'>
# 3

# %%
#one line way
name = ["asha", "ravi", "asha", "meera", "ravi"]
unique_name = list(set(name))
print(unique_name)
# Out:
# ['asha', 'meera', 'ravi']

# %%
#For loop way
name = ["asha", "ravi", "asha", "meera", "ravi"]
unique = []
for el in name :
    if el not in unique :
        unique.append(el)
    else :
        pass
print(unique)
# Out:
# ['asha', 'ravi', 'meera']

# %%
#dictionary mapping
names = ["asha", "ravi", "asha", "meera", "ravi"]
name_length = {}
for name in names:
    name_length[name] = len(name)
print(name_length)
# Out:
# {'asha': 4, 'ravi': 4, 'meera': 5}

# %%
#find the largest, the smallest, and the average
numbers = [12, 45, 50, 65, 84, 72]
largest = numbers[0]
smallest = numbers[0]
total = 0

for num in numbers :
    if num > largest :
        largest = num
    if num < smallest :
        smallest = num
    total += num

average = total / len(numbers)
print ("largest =" , largest )
print ("smallest : " , smallest )
print ("average : " , average )
# Out:
# largest = 84
# smallest :  12
# average :  54.666666666666664

# %%
4. Fizzbuzz.py

# %%
for i in range (1,101) :
    if i % 3 == 0 and i % 5 == 0 :
        print ("FizzBuzz")
    elif i % 3 == 0 :
        print ("Fizz")
    elif i % 5 == 0 :
        print ("Buzz")
    else :
        print (i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %%
result = []
for i in range (1,101) :
    if i % 3 == 0 and i % 5 == 0 :
        result.append("FizzBuzz")
    elif i % 3 == 0 :
        result.append("Fizz")
    elif i % 5 == 0 :
        result.append("Buzz")
    else :
        result.append(i)
print(result)
# Out:
# [1, 2, 'Fizz', 4, 'Buzz', 'Fizz', 7, 8, 'Fizz', 'Buzz', 11, 'Fizz', 13, 14, 'FizzBuzz', 16, 17, 'Fizz', 19, 'Buzz', 'Fizz', 22, 23, 'Fizz', 'Buzz', 26, 'Fizz', 28, 29, 'FizzBuzz', 31, 32, 'Fizz', 34, 'Buzz', 'Fizz', 37, 38, 'Fizz', 'Buzz', 41, 'Fizz', 43, 44, 'FizzBuzz', 46, 47, 'Fizz', 49, 'Buzz', 'Fizz', 52, 53, 'Fizz', 'Buzz', 56, 'Fizz', 58, 59, 'FizzBuzz', 61, 62, 'Fizz', 64, 'Buzz', 'Fizz', 67, 68, 'Fizz', 'Buzz', 71, 'Fizz', 73, 74, 'FizzBuzz', 76, 77, 'Fizz', 79, 'Buzz', 'Fizz', 82, 83, 'Fizz', 'Buzz', 86, 'Fizz', 88, 89, 'FizzBuzz', 91, 92, 'Fizz', 94, 'Buzz', 'Fizz', 97, 98, 'Fizz', 'Buzz']

# %%
def fizzbuzz(limit, div1, word1, div2, word2):
    result = []
    
    for i in range (1, limit +1):
        text = ""
        if i % div1 == 0 :
            text += word1
        if i % div2 == 0 :
            text += word2
        if text == "" :
            text = str(i)
            
        result.append(text)
    
    return result

print (fizzbuzz(100,2,"EVEN",7,"bye"))
# Out:
# ['1', 'EVEN', '3', 'EVEN', '5', 'EVEN', 'bye', 'EVEN', '9', 'EVEN', '11', 'EVEN', '13', 'EVENbye', '15', 'EVEN', '17', 'EVEN', '19', 'EVEN', 'bye', 'EVEN', '23', 'EVEN', '25', 'EVEN', '27', 'EVENbye', '29', 'EVEN', '31', 'EVEN', '33', 'EVEN', 'bye', 'EVEN', '37', 'EVEN', '39', 'EVEN', '41', 'EVENbye', '43', 'EVEN', '45', 'EVEN', '47', 'EVEN', 'bye', 'EVEN', '51', 'EVEN', '53', 'EVEN', '55', 'EVENbye', '57', 'EVEN', '59', 'EVEN', '61', 'EVEN', 'bye', 'EVEN', '65', 'EVEN', '67', 'EVEN', '69', 'EVENbye', '71', 'EVEN', '73', 'EVEN', '75', 'EVEN', 'bye', 'EVEN', '79', 'EVEN', '81', 'EVEN', '83', 'EVENbye', '85', 'EVEN', '87', 'EVEN', '89', 'EVEN', 'bye', 'EVEN', '93', 'EVEN', '95', 'EVEN', '97', 'EVENbye', '99', 'EVEN']

# %%
5. Functions_practice.py

# %%
def greet(name = "Friend"):
    return "Hello!" + name

print(greet())
print(greet("chirag"))
# Out:
# Hello!Friend
# Hello!chirag

# %%
def greet(name = "Friend"):
    return "Hello!" + name

def get_avg(num) :
    if len(num) == 0 :
        return None
    return sum(num) / len(num)

print(greet())
print(greet("chirag"))
marks = [75, 10, 85, 45, 16]
print("Average marks : " , get_avg(marks))
empty_list = []
print("Average of empty list : ", get_avg(empty_list))
# Out:
# Hello!Friend
# Hello!chirag
# Average marks :  46.2
# Average of empty list :  None

# %%
6. Errors_practice.py

# %%
print(name)
#Name error as name is not defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(name)
#
# NameError: name 'name' is not defined

# %%
print(10+'5')
#Type error : As we know that adding int to int  str to str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 #Type error as
# ----> 2 print(10+'5')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
num = [1, 2, 3, 4]
print(num[5])
#Index error : number 4 is on index 3 not 5 and there is no number at index 5 so the error has been occured.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 num = [1, 2, 3, 4]
# ----> 2 print(num[5])
#
# IndexError: list index out of range

# %%
student = { "name" : "chirag" }
print(student[age])
#Keyerror : i put the value of a key which is not exist.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 student = { "name" : "chirag" }
# ----> 2 print(student[age])
#
# NameError: name 'age' is not defined

# %%
print(10/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 print(10/0)
#
# ZeroDivisionError: division by zero

# %%
#Zero division error : number divided by zero so the error has occurred.

# %%
try :
    name = chirag
except Exception as e :
    print(str(e))
print("Friendly message : the name is not defined")
# Out:
# name 'chirag' is not defined
# Friendly message : the name is not defined
