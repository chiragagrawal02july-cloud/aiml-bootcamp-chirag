# %%
Day1 Task

# %%
1. types_practice.py

# %%
a = 1
b = 2
sum = a+b
print(sum)
print (type(a and b))
# Out:
# 3
# <class 'int'>

# %%
a = 3.14
print (type(a))
# Out:
# <class 'float'>

# %%
name = "chirag"
print(name)
print (type(name))
# Out:
# chirag
# <class 'str'>

# %%
chirag_is = True
chirag_are= False
print(chirag_are)
print(type(chirag_is))
# Out:
# False
# <class 'bool'>

# %%
fruits = ["banana", "orange", "kiwi"]
print(fruits)
print(type(fruits))
# Out:
# ['banana', 'orange', 'kiwi']
# <class 'list'>

# %%
student = {
    "name" : "chirag",
    "roll no" : 17,
    "marks" : 210,
}
print(student)
print(type(student))
# Out:
# {'name': 'chirag', 'roll no': 17, 'marks': 210}
# <class 'dict'>

# %%
name = ["chirag", 25]
print(name)
#syntax invailid we can not write the code in this way
# Out:
# ['chirag', 25]

# %%
2. Mutability.py

# %%
a = [1,2,3]
b = a
b.append(4)
print(a)
print(b)
#append add the number at the last so the value to a and b has been changed.
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
3. collections_practice.py

# %%
name = {"asha", "ravi", "asha", "meera", "ravi"}
print(name)
print(type(name))
print(len(name))
# Out:
# {'ravi', 'meera', 'asha'}
# <class 'set'>
# 3

# %%
name = ["asha", "ravi", "asha", "meera", "ravi"]
unique_name = list(set(name))
print(unique_name)
# Out:
# ['ravi', 'meera', 'asha']

# %%
4. fizzbuzz.py
