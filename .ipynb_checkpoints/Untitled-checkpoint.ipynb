# %%
number = int(input("enter your number : "))
if (number % 7 == 0) :
    print(True)
else :
    print(False)
# Out:
# enter your number :  63
# True

# %%
def square(num):
    return num*num

print(square(5))
# Out:
# 25
