# %% [markdown]
# day 1

# %%
a = 10 
b = -25 
print(type (a))
a = 10
b = 20
sum = a + b
print(sum)
# Out:
# <class 'int'>
# 30

# %%
Price = 99.95
pi = 3.14
print (type(Price))
print (type (pi))
# Out:
# <class 'float'>
# <class 'float'>

# %%
name = 'chirag'
print(type(name))
# Out:
# <class 'str'>

# %%
is_student = True
is_logged_in = False
print(type(is_student))
# Out:
# <class 'bool'>

# %%
chirag_is = True
chirag_are = False
print(type(chirag_is))
# Out:
# <class 'bool'>

# %%
name = "chirag", "vaibhav", "sanjeev"
print(name)
print(type(name))
car = "bmw", "scorpio"
print(car)
print(type(car))
fruits = "orange", "banana"
print(fruits)
print (type(fruits))
# Out:
# ('chirag', 'vaibhav', 'sanjeev')
# <class 'tuple'>
# ('bmw', 'scorpio')
# <class 'tuple'>
# ('orange', 'banana')
# <class 'tuple'>

# %%
student = {'name' : "Chirag",
        "age" : '24',
         "City" : 'Jaipur'
}
print(student)
# Out:
# {'name': 'Chirag', 'age': '24', 'City': 'Jaipur'}

# %%
a = [1,2,3]
b=a
b.append(4)
print(a)
print(b)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
names = ['asha', 'meera', 'ravi', 'asha', 'ravi']
unique = []
for n in names :
    if n not in unique :
        unique.append(n)
print(unique)
# Out:
# ['asha', 'meera', 'ravi']

# %%
or n in range (1,101) :
    if n % 3 == 0 and n % 5 == 0 : 
        print("FizzBuzz")
    if n % 3 == 0 : 
        print("Fizz")
    if n % 5 == 0 : 
        print("Buzz")
    else : 
        print(n)
# Out:
#   Cell In[11], line 1
#     or n in range (1,101) :
#     ^
# SyntaxError: invalid syntax

# %%
def greet("asha"):
    return f"hello, {"chirag"}!"

print(greet("asha")
# Out:
#   Cell In[12], line 1
#     def greet("asha"):
#               ^
# SyntaxError: invalid syntax
